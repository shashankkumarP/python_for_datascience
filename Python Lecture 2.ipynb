# %% [markdown]
# # NUMBERS

# %%
#Addition
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
#Floor Division
9//4
# Out:
# 2

# %%
#Modulo
7%4
# Out:
# 3

# %%
#Power
2**3
# Out:
# 8

# %%
2**0.5
# Out:
# 1.4142135623730951

# %%
round(2**0.5,3)
# Out:
# 1.414

# %%
2 + 10 * 10 + 2
# Out:
# 104

# %%
(2 + 10) * (10 + 2)
# Out:
# 144

# %% [markdown]
# # Variable Assignment

# %%
a = 5

# %%
a
# Out:
# 40

# %%
a
# Out:
# 40

# %%
a
# Out:
# 40

# %%
a + a
# Out:
# 10

# %%
#Reassignment
a = a + a

# %%
my_income = 100
tax_rate = 0.1
my_taxes = my_income*tax_rate

# %%
my_taxes
# Out:
# 10.0

# %%
my_dogs = 2

# %%
my_dogs
# Out:
# 2

# %%
my_dogs = ["Sammy","Frankie"]

# %%
my_dogs
# Out:
# ['Sammy', 'Frankie']

# %%
a = a + 10

# %%
a
# Out:
# 50

# %%
a += 10

# %%
a
# Out:
# 60

# %%
a *= 2

# %%
a
# Out:
# 120

# %% [markdown]
# int
# float
# str
# list
# tuples
# dict
# set
# bool

# %%
type(a)
# Out:
# int

# %%
b = 1.2

# %%
b
# Out:
# 1.2

# %%
type(b)
# Out:
# float

# %%
a = (1,2)

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# # String

# %%
'hello'
# Out:
# 'hello'

# %%
"This is also a string"
# Out:
# 'This is also a string'

# %%
'2'
# Out:
# '2'

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"Hello World 1"
# Out:
# 'Hello World 1'

# %%
"Hello World 1"
"Hello World 2"
# Out:
# 'Hello World 2'

# %%
print("Hello World 1")
print("Hello World 2")
print("Hello World 3")
print("Hello World 4")
# Out:
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4

# %%
print("Hello World 1")
print("Hello World 2")
print("Hello World 3")
print('\n')   #Next Line
print("Hello World 4")
# Out:
# Hello World 1
# Hello World 2
# Hello World 3
#
#
# Hello World 4

# %%
len("Hello World 1")
# Out:
# 13

# %% [markdown]
# String Indexing

# %%
s = "Hello World"

# %%
s
# Out:
# 'Hello World'

# %%
print(s)
# Out:
# Hello World

# %%
s[0] #First letter
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
s[-1]
# Out:
# 'd'

# %%
#Grab every element except the first
s[1:]
# Out:
# 'ello World'

# %%
s[2:] #sTARTING
# Out:
# 'llo World'

# %%
s[:3] #ENDING
# Out:
# 'Hel'

# %%
s[:5]
# Out:
# 'Hello'

# %%
#Everything
s[:]
# Out:
# 'Hello World'

# %%
#Step Size
s[::1]
# Out:
# 'Hello World'

# %%
s[::2]
# Out:
# 'HloWrd'

# %%
s[::3]
# Out:
# 'HlWl'

# %%
s[::-1]
# Out:
# 'dlroW olleH'

# %%
s[2::-2]
# Out:
# 'lH'

# %%
s[::-4]
# Out:
# 'dWl'

# %%
s
# Out:
# 'Hello World'

# %%
s[::-2]
# Out:
# 'drWolH'

# %%
s[3::-2]
# Out:
# 'le'

# %%
s + ' concatenate me'
# Out:
# 'Hello World concatenate me'

# %%
s = s + ' concatenate me'

# %%
s
# Out:
# 'Hello World concatenate me'

# %%
letter = 'z'

# %%
letter*1000
# Out:
# '...'

# %%
s
# Out:
# 'Hello World concatenate me'

# %%
s.upper()
# Out:
# 'HELLO WORLD CONCATENATE ME'

# %%
s.lower()
# Out:
# 'hello world concatenate me'

# %%
s.split()
# Out:
# ['Hello', 'World', 'concatenate', 'me']

# %%
s.split('w')
# Out:
# ['Hello World concatenate me']

# %%
s.split('o')
# Out:
# ['Hell', ' W', 'rld c', 'ncatenate me']

# %% [markdown]
# # Print Formating

# %%
print('I m going to inject %s here.' % 'this also')
# Out:
# I m going to inject this also here.

# %%
print('I m going to inject %r here text here, and %s text here.' % ('2.55', 'also'))
# Out:
# I m going to inject '2.55' here text here, and also text here.

# %%
print('He said his name was %s.'% 'Fred')
print('He said his name was %r.'% 'Fred')
# Out:
# He said his name was Fred.
# He said his name was 'Fred'.

# %%
print('I wrote %s program today.' %3.75)
print('I wrote %d program today.' %3.75)  #return in the output in the form of integer
# Out:
# I wrote 3.75 program today.
# I wrote 3 program today.

# %%
print('Floating point number: %8.2f' %(13.14444))
# Out:
# Floating point number:    13.14

# %%
print('Floating point number: %0.2f' %(13.14444))
# Out:
# Floating point number: 13.14

# %%
print('Floating point number: %0.3f' %(13.14444))
# Out:
# Floating point number: 13.144

# %%
print('Floating point number: %20.3f' %(13.14444))
# Out:
# Floating point number:               13.144

# %%
print("This is a string with an {}".format('insert'))
# Out:
# This is a string with an insert

# %%
print('The {2} {1} {0}'.format('fox','brown','quick'))
# Out:
# The quick brown fox

# %%
print('The {1} {2} {0}'.format('fox','brown','quick'))
# Out:
# The brown quick fox

# %%
print('The {1} {1} {0}'.format('fox','brown','quick'))
# Out:
# The brown brown fox

# %% [markdown]
# # LIST

# %%
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list = ['string', 23, 23.3,'o']

# %%
my_list
# Out:
# ['string', 23, 23.3, 'o']

# %%
len(my_list)
# Out:
# 4

# %%
my_list = ['one','two','three',4.5]

# %%
my_list[0]
# Out:
# 'one'

# %%
my_list[::-1]
# Out:
# [4.5, 'three', 'two', 'one']

# %%
#Reassignment
my_list = my_list + ['add new item permanently']

# %%
my_list
# Out:
# ['one', 'two', 'three', 4.5, 'add new item permanently']

# %%
my_list * 2
# Out:
# ['one',
#  'two',
#  'three',
#  4.5,
#  'add new item permanently',
#  'one',
#  'two',
#  'three',
#  4.5,
#  'add new item permanently']

# %%
list1 = [1,2,3]

# %%
list1.append('append me!')

# %%
list1
# Out:
# [1, 2, 3, 'append me!']

# %%
list1.pop(3)
# Out:
# 'append me!'

# %%
list1
# Out:
# [1, 2, 3]

# %%
list1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-156-af6d2015fa1f> in <module>
# ----> 1 list1[100]
#
# IndexError: list index out of range

# %%
new_list = ['a','e','i','o','u']

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['u', 'o', 'i', 'e', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
new

# %%
new_list1 = [2,'e',1,'z','u']

# %%
new_list1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-cfa05d8f48b5> in <module>
# ----> 1 new_list1.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
new_list2 = [2,3,1,4,0]

# %%
new_list2.sort()

# %%
new_list2
# Out:
# [0, 1, 2, 3, 4]

# %%
lst_1 = [1,2,3]
lst_2 = [4,5,6]
lst_3 = [6,7,8]

# %%
matrix = [lst_1,lst_2,lst_3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [6, 7, 8]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[1][1]
# Out:
# 5

# %% [markdown]
# # DICTIONARIES

# %%
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key2']
# Out:
# 'value2'

# %%
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
my_dict
# Out:
# {'key1': 123, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %%
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
my_dict['key3'][1]
# Out:
# 'item1'

# %%
my_dict['key3'][1].upper()
# Out:
# 'ITEM1'

# %%
my_dict['key1']
# Out:
# 123

# %%
my_dict['key1'] = my_dict['key1'] - 123

# %%
my_dict
# Out:
# {'key1': 0, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %%
d = {}

# %%
d['animal'] = 'Dog'

# %%
d['answer'] = 42

# %%
d
# Out:
# {'answer': 42, 'animal': 'Dog'}

# %%
my_dict['key2'][1] = my_dict['key2'][1] - 23

# %%
my_dict
# Out:
# {'key1': 0, 'key2': [12, 0, 33], 'key3': ['item0', 'item1', 'item2']}

# %%
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
d['key1']['nestkey']
# Out:
# {'subnestkey': 'value'}

# %%
d
# Out:
# {'key1': {'nestkey': {'subnestkey': 'value'}}}

# %%
d = {'key1': 1,'key2':2,'key3':3}

# %%
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
list(d.values())[1]
# Out:
# 2

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])

# %% [markdown]
# # TUPLES

# %%
t = (1,2,3)

# %%
len(t)
# Out:
# 3

# %%
t = ('one', 2)

# %%
t
# Out:
# ('one', 2)

# %%
t[0]
# Out:
# 'one'

# %%
t.index('one')
# Out:
# 0

# %%
t.index(2)
# Out:
# 1

# %%
t[0] = 'change'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-245-9468ef3b159f> in <module>
# ----> 1 t[0] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = ['one',2]

# %%
l
# Out:
# ['one', 2]

# %%
l[0] = 'change'

# %%
l
# Out:
# ['change', 2]

# %%
t.append('nope')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-250-b75f5b09ac19> in <module>
# ----> 1 t.append('nope')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t*2
# Out:
# ('one', 2, 'one', 2)

# %%
t
# Out:
# ('one', 2)

# %% [markdown]
# # SETS AND BOOLEANS

# %%
x = set()

# %%
x.add(2)

# %%
x.add(1)

# %%
x
# Out:
# {1, 2}

# %%
x = {2,1,1,1,1,2,2,2,2,2}

# %%
x
# Out:
# {1, 2}

# %%
list1 =  {6,6,True,4,5,2,3,2,2,2,1}

# %%
list1 =  {1,6,1,1,0,False,4,1,5,2,3,2,2,2,0}

# %%
list1 =  {1,6,1,1,'True','True',4,1,5,2,3,2,2,2}

# %%
set(list1)
# Out:
# {True, 2, 3, 4, 5, 6}

# %% [markdown]
# BOOLEANS

# %%
a = True

# %%
a
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
a != False #Not Equal true
# Out:
# True

# %%
b = None

# %%
b
